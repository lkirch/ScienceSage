# %% [markdown]
# ### Examining chunks.jsonl

# %%
import json
import pandas as pd

# %%
with open("../data/processed/chunks.jsonl", "r", encoding="utf-8") as f:
    chunk_dicts = [json.loads(line) for line in f]

df = pd.DataFrame(chunk_dicts)
print(f"Loaded {len(df)} chunks.")
df.info()
# Out:
# Loaded 2116 chunks.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2116 entries, 0 to 2115
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   uuid         2116 non-null   object
#  1   text         2116 non-null   object
#  2   title        2116 non-null   object
#  3   source_url   2116 non-null   object
#  4   categories   2116 non-null   object
#  5   images       2116 non-null   object
#  6   summary      2116 non-null   object
#  7   chunk_index  2116 non-null   int64
#  8   char_start   2116 non-null   int64
#  9   char_end     2116 non-null   int64
#  10  created_at   2116 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 182.0+ KB

# %%
df.duplicated(subset=['text', 'title', 'source_url', 'chunk_index']).sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                                    uuid  \
# 0  ae6fe91d-1fb3-599d-bc47-a2fc226295df
# 1  6d984cb0-f909-5f93-a779-a229c3485e72
# 2  8c3b19df-f41b-520c-9748-55547ad84d8a
# 3  88cc69c4-de7a-5128-87dc-bb3416400847
# 4  70c55fdc-9096-541a-9f84-e6075ce6e92e
#
#                                                 text  \
# 0  Discovery and exploration of the Solar System ...
# 1  Pre-telescope\nThe first humans had limited un...
# 2  Though unclear if motivated by empirical obser...
# 3  Heliocentric model\nVarious astronomers, espec...
# 4  Telescopic observations\nEarly telescopic disc...
#
#                                            title  \
# 0  Discovery and exploration of the Solar System
# 1  Discovery and exploration of the Solar System
# 2  Discovery and exploration of the Solar System
# 3  Discovery and exploration of the Solar System
# 4  Discovery and exploration of the Solar System
#
#                                           source_url  \
# 0  https://en.wikipedia.org/wiki/Discovery_and_ex...
# 1  https://en.wikipedia.org/wiki/Discovery_and_ex...
# 2  https://en.wikipedia.org/wiki/Discovery_and_ex...
# 3  https://en.wikipedia.org/wiki/Discovery_and_ex...
# 4  https://en.wikipedia.org/wiki/Discovery_and_ex...
#
#                                           categories  \
# 0  [Category:All Wikipedia articles in need of up...
# 1  [Category:All Wikipedia articles in need of up...
# 2  [Category:All Wikipedia articles in need of up...
# 3  [Category:All Wikipedia articles in need of up...
# 4  [Category:All Wikipedia articles in need of up...
#
#                                               images  \
# 0  [https://upload.wikimedia.org/wikipedia/common...
# 1  [https://upload.wikimedia.org/wikipedia/common...
# 2  [https://upload.wikimedia.org/wikipedia/common...
# 3  [https://upload.wikimedia.org/wikipedia/common...
# 4  [https://upload.wikimedia.org/wikipedia/common...
#
#                                              summary  chunk_index  char_start  \
# 0  Discovery and exploration of the Solar System ...            0           0
# 1  Discovery and exploration of the Solar System ...            1        2402
# 2  Discovery and exploration of the Solar System ...            2        4781
# 3  Discovery and exploration of the Solar System ...            3        6325
# 4  Discovery and exploration of the Solar System ...            4        8643
#
#    char_end                        created_at
# 0      2402  2025-09-27T15:40:45.840665+00:00
# 1      4781  2025-09-27T15:40:45.840720+00:00
# 2      6325  2025-09-27T15:40:45.840742+00:00
# 3      8643  2025-09-27T15:40:45.840759+00:00
# 4      9568  2025-09-27T15:40:45.840776+00:00
